# %% [markdown]
# # Clay MAE Reconstruction
#
# This notebook demonstrates the Masked Autoencoder (MAE) reconstruction
# capability of Clay v1.5. We will:
#
# 1. Fetch Sentinel-2 imagery from the Element84 STAC catalog
# 2. Load the model with 70% masking enabled
# 3. Run the full encoder + decoder forward pass
# 4. Visualize original, masked, and reconstructed images side by side
#
# The MAE training objective teaches the model to reconstruct masked patches
# from visible ones, which forces it to learn rich spatial and spectral
# representations.
#
# **Requirements**: `pip install claymodel stackstac pystac-client geopandas matplotlib einops`

# %%
import math
import os

import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pystac_client
import stackstac
import torch
from einops import rearrange
from rasterio.enums import Resampling
from shapely import Point
from torchvision.transforms import v2

from claymodel.module import ClayMAEModule

# %% [markdown]
# ### Fetch Sentinel-2 imagery
#
# We use the same Monchique, Portugal location as the wall-to-wall tutorial.
# We fetch a few cloud-free scenes so we can show reconstruction on multiple dates.

# %%
# Point over Monchique, Portugal
lat, lon = 37.30939, -8.57207

# Date range spanning the 2018 fire season
start = "2018-07-01"
end = "2018-09-01"

# %%
# Sentinel-2 bands that match metadata.yaml band_order
S2_BANDS = [
    "blue",
    "green",
    "red",
    "rededge1",
    "rededge2",
    "rededge3",
    "nir",
    "nir08",
    "swir16",
    "swir22",
]

# Search the Element84 STAC catalog
STAC_API = "https://earth-search.aws.element84.com/v1"
catalog = pystac_client.Client.open(STAC_API)

search = catalog.search(
    collections=["sentinel-2-l2a"],
    datetime=f"{start}/{end}",
    bbox=(lon - 1e-5, lat - 1e-5, lon + 1e-5, lat + 1e-5),
    max_items=100,
    query={"eo:cloud_cover": {"lt": 80}},
)
all_items = search.item_collection()

# Deduplicate by date, take up to 4 for visualization
items, dates = [], []
for item in all_items:
    if item.datetime.date() not in dates:
        items.append(item)
        dates.append(item.datetime.date())

items = items[:4]
print(f"Using {len(items)} items")

# %%
# Create bounding box for 256x256 chips at 10m
epsg = int(items[0].properties["proj:code"].replace("EPSG:", ""))

poidf = gpd.GeoDataFrame(
    pd.DataFrame(),
    crs="EPSG:4326",
    geometry=[Point(lon, lat)],
).to_crs(epsg)

coords = poidf.iloc[0].geometry.coords[0]

size = 256
gsd = 10
bounds = (
    coords[0] - (size * gsd) // 2,
    coords[1] - (size * gsd) // 2,
    coords[0] + (size * gsd) // 2,
    coords[1] + (size * gsd) // 2,
)

# %%
# Download the imagery stack
stack = stackstac.stack(
    items,
    bounds=bounds,
    snap_bounds=False,
    epsg=epsg,
    resolution=gsd,
    dtype="float64",
    rescale=False,
    fill_value=0,
    assets=S2_BANDS,
    resampling=Resampling.nearest,
)
stack = stack.compute()
print(f"Stack shape: {stack.shape}  (time, band, y, x)")

# %%
# Visualize RGB for each date
fig, axes = plt.subplots(1, len(items), figsize=(4 * len(items), 4))
if len(items) == 1:
    axes = [axes]
for i, ax in enumerate(axes):
    rgb = stack.isel(time=i).sel(band=["red", "green", "blue"]).values
    ax.imshow(np.clip(rgb.transpose(1, 2, 0) / 3000, 0, 1))
    ax.set_title(str(dates[i]), fontsize=9)
    ax.set_axis_off()
plt.suptitle("Input Sentinel-2 imagery (RGB)", fontsize=12)
plt.tight_layout()

# %% [markdown]
# ### Load the model for reconstruction
#
# For reconstruction, we need:
# - `mask_ratio=0.7` — mask 70% of patches (the model must reconstruct them)
# - `shuffle=True` — randomly select which patches to mask
#
# This matches the training configuration.

# %%
# Find or download checkpoint
ckpt = "clay-v1.5.ckpt"
if not os.path.exists(ckpt):
    ckpt = "../../clay-v1.5.ckpt"
if not os.path.exists(ckpt):
    print("Downloading checkpoint...")
    os.system(
        "wget -q https://huggingface.co/made-with-clay/Clay/resolve/main/"
        "v1.5/clay-v1.5.ckpt -O clay-v1.5.ckpt"
    )
    ckpt = "clay-v1.5.ckpt"

# %%
from claymodel.api import _bundled_metadata_path, load_metadata

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
torch.set_default_device(device)

metadata = load_metadata()

# Load with masking enabled for reconstruction
model = ClayMAEModule.load_from_checkpoint(
    ckpt,
    metadata_path=_bundled_metadata_path(),
    mask_ratio=0.7,
    shuffle=True,
)
model.eval()
model = model.to(device)
print(f"Model loaded on {device} with mask_ratio=0.7")

# %% [markdown]
# ### Prepare the datacube

# %%
def normalize_timestamp(date):
    """Encode date as cyclic (sin, cos) features for week and hour."""
    week = date.isocalendar().week * 2 * np.pi / 52
    hour = date.hour * 2 * np.pi / 24
    return (math.sin(week), math.cos(week)), (math.sin(hour), math.cos(hour))


def normalize_latlon(lat, lon):
    """Encode lat/lon as (sin, cos) features."""
    lat = lat * np.pi / 180
    lon = lon * np.pi / 180
    return (math.sin(lat), math.cos(lat)), (math.sin(lon), math.cos(lon))


# Extract normalization stats and wavelengths from metadata
platform = "sentinel-2-l2a"

mean = [metadata[platform].bands.mean[b] for b in stack.band.values]
std = [metadata[platform].bands.std[b] for b in stack.band.values]
waves = [metadata[platform].bands.wavelength[b] for b in stack.band.values]

transform = v2.Compose([v2.Normalize(mean=mean, std=std)])

# Normalize pixels
pixels = torch.from_numpy(stack.values.astype(np.float32))
pixels = transform(pixels)

# Encode timestamps
datetimes = stack.time.values.astype("datetime64[s]").tolist()
times = [normalize_timestamp(dt) for dt in datetimes]
week_norm = [t[0] for t in times]
hour_norm = [t[1] for t in times]

# Encode location (same for all dates)
latlons = [normalize_latlon(lat, lon)] * len(times)
lat_norm = [ll[0] for ll in latlons]
lon_norm = [ll[1] for ll in latlons]

# Build the datacube dictionary
datacube = {
    "pixels": pixels.to(device),
    "time": torch.tensor(
        np.hstack((week_norm, hour_norm)), dtype=torch.float32, device=device
    ),
    "latlon": torch.tensor(
        np.hstack((lat_norm, lon_norm)), dtype=torch.float32, device=device
    ),
    "gsd": torch.tensor(metadata[platform].gsd, device=device),
    "waves": torch.tensor(waves, device=device),
}

print(f"pixels:  {datacube['pixels'].shape}")
print(f"time:    {datacube['time'].shape}")
print(f"latlon:  {datacube['latlon'].shape}")
print(f"waves:   {datacube['waves'].shape}")
print(f"gsd:     {datacube['gsd']}")

# %% [markdown]
# ### Run the full encoder + decoder forward pass
#
# The encoder produces embeddings for the unmasked 30% of patches.
# The decoder takes these plus learnable mask tokens and reconstructs
# the full image.

# %%
with torch.no_grad():
    # Encoder: embed visible patches
    unmsk_patch, unmsk_idx, msk_idx, msk_matrix = model.model.encoder(datacube)

    # Decoder: reconstruct all patches from visible ones + mask tokens
    rec_pixels, _ = model.model.decoder(
        unmsk_patch,
        unmsk_idx,
        msk_idx,
        msk_matrix,
        datacube["time"],
        datacube["latlon"],
        datacube["gsd"],
        datacube["waves"],
    )

print(f"Encoder output: {unmsk_patch.shape}")
print(f"Decoder output: {rec_pixels.shape}")
print(f"Mask matrix:    {msk_matrix.shape} (1=masked, 0=visible)")
print(f"Masked patches: {int(msk_matrix.sum(dim=1)[0].item())} / {msk_matrix.shape[1]}")

# %% [markdown]
# ### Reshape decoder output back to pixel space
#
# The decoder outputs `[B, num_patches, C * patch_size^2]` which we
# rearrange back into `[B, C, H, W]` images.

# %%
num_channels = datacube["pixels"].shape[1]

# Rearrange decoder patches into pixel space
rec_images = rearrange(
    rec_pixels,
    "b (h w) (c p1 p2) -> b c (h p1) (w p2)",
    c=num_channels,
    h=32,
    w=32,
    p1=8,
    p2=8,
)
print(f"Reconstructed images: {rec_images.shape}")

# %% [markdown]
# ### Denormalize for visualization
#
# Both the original normalized pixels and the reconstruction are in z-score
# space. We denormalize to get back to reflectance values for display.

# %%
def denormalize_images(images_np, means, stds):
    """Reverse z-score normalization: images * std + mean"""
    means = np.array(means).reshape(1, -1, 1, 1)
    stds = np.array(stds).reshape(1, -1, 1, 1)
    return images_np * stds + means


# Denormalize original input
orig_np = datacube["pixels"].cpu().numpy()
orig_denorm = denormalize_images(orig_np, mean, std)

# Denormalize reconstruction
rec_np = rec_images.cpu().numpy()
rec_denorm = denormalize_images(rec_np, mean, std)

# %% [markdown]
# ### Create masked version for visualization
#
# We overlay the mask matrix on the original image to show which patches
# were hidden from the encoder.

# %%
# Expand mask matrix from patch-level (32x32) to pixel-level (256x256)
mask_pixels = rearrange(
    msk_matrix.cpu().numpy(),
    "b (h w) -> b h w",
    h=32,
    w=32,
)
# Repeat each patch mask value across the 8x8 pixel patch
mask_pixels = np.repeat(np.repeat(mask_pixels, 8, axis=1), 8, axis=2)
# mask_pixels: [B, 256, 256], 1=masked, 0=visible

print(f"Mask shape: {mask_pixels.shape}")

# %% [markdown]
# ### Visualize: Original, Masked, and Reconstructed
#
# For each date we show:
# 1. **Original** — the full input image
# 2. **Masked** — what the encoder sees (30% of patches)
# 3. **Reconstructed** — the decoder's reconstruction from only visible patches
#
# We display RGB bands (red, green, blue = indices 2, 1, 0 in our band order).

# %%
# RGB band indices in our band_assets list:
# blue=0, green=1, red=2 -> RGB = [2, 1, 0]
rgb_idx = [2, 1, 0]
vmax = 3000  # Sentinel-2 reflectance clipping value

n_images = min(len(items), 4)
fig, axes = plt.subplots(n_images, 3, figsize=(12, 4 * n_images))
if n_images == 1:
    axes = axes[np.newaxis, :]

for i in range(n_images):
    # Original RGB
    orig_rgb = orig_denorm[i, rgb_idx].transpose(1, 2, 0)
    axes[i, 0].imshow(np.clip(orig_rgb / vmax, 0, 1))
    axes[i, 0].set_title(f"Original ({dates[i]})")
    axes[i, 0].set_axis_off()

    # Masked RGB (gray out masked patches)
    masked_rgb = orig_rgb.copy()
    masked_rgb[mask_pixels[i] == 1] = [vmax * 0.5, vmax * 0.5, vmax * 0.5]
    axes[i, 1].imshow(np.clip(masked_rgb / vmax, 0, 1))
    axes[i, 1].set_title("Masked (30% visible)")
    axes[i, 1].set_axis_off()

    # Reconstructed RGB
    rec_rgb = rec_denorm[i, rgb_idx].transpose(1, 2, 0)
    axes[i, 2].imshow(np.clip(rec_rgb / vmax, 0, 1))
    axes[i, 2].set_title("Reconstructed")
    axes[i, 2].set_axis_off()

plt.suptitle("Clay MAE: Original → Masked (70%) → Reconstructed", fontsize=14)
plt.tight_layout()

# %% [markdown]
# ### Reconstruction error map
#
# We can also look at the per-pixel reconstruction error to see where the
# model struggles. Higher error often occurs at sharp boundaries or unusual features.

# %%
fig, axes = plt.subplots(1, n_images, figsize=(4 * n_images, 4))
if n_images == 1:
    axes = [axes]

for i in range(n_images):
    # Mean absolute error across bands
    error = np.abs(orig_denorm[i] - rec_denorm[i]).mean(axis=0)
    im = axes[i].imshow(error, cmap="hot", vmin=0, vmax=500)
    axes[i].set_title(f"MAE error ({dates[i]})")
    axes[i].set_axis_off()

plt.colorbar(im, ax=axes[-1], shrink=0.8, label="Mean Abs Error")
plt.tight_layout()

# %% [markdown]
# ## Summary
#
# This notebook demonstrated the Clay v1.5 MAE reconstruction pipeline:
#
# 1. **Fetched multi-temporal Sentinel-2 data** from the Element84 STAC catalog
# 2. **Loaded the model with 70% masking** -- the same ratio used during training
# 3. **Ran the encoder** on visible patches (30%) to produce embeddings
# 4. **Ran the decoder** to reconstruct all patches from the sparse visible set
# 5. **Visualized original vs masked vs reconstructed** images side by side
# 6. **Computed per-pixel reconstruction error** to identify where the model struggles
#
# Key takeaways:
# - The model reconstructs plausible imagery from only 30% of visible patches, demonstrating
#   that it has learned strong spatial and spectral priors
# - Reconstruction quality varies across scenes -- clouds, sharp edges, and unusual features
#   tend to have higher error
# - Reconstruction error can serve as a quality signal: harder-to-reconstruct images may
#   contain novel or anomalous features (see ELLE quality scoring in `claymodel.inference`)
#
# Next steps:
# - Try different `mask_ratio` values (0.5, 0.8, 0.9) to see how quality degrades
# - Compare reconstruction across sensors (Landsat, Sentinel-1 SAR)
# - Use reconstruction error as an anomaly detection signal
# - See `embeddings.ipynb` for working with the encoder-only embedding path
